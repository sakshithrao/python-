# %%
#if  else
num=int(input("enter the number:"))
if num>0:
        print("num is +ve")
else:
        print("num is -ve")
# Out:
# enter the number: 99
# num is +ve

# %%
num=int(input())

if num % 3 ==0 and  num % 5 == 0:
    print(f"{num} divisible with both 3 and 5")
else:
    print(f"{num} not divisible with both 3 and 5")
# Out:
#  15
# 15 divisible with both 3 and 5

# %%
#checking wether the number is perfect squere or not 
num= int(input())
val=num** 0.5
print(val)
if val == int(val):
    print(f"{num} is perfect square")
else:
    print(f"{num} is not a perfect square")
# Out:
#  4
# 2.0
# 4 is perfect square

# %%
num= int(input())
val=num** 0.5
print(val)
if val == (val):
    print("num is perfect square")
else:
    print("num is not a perfect square")

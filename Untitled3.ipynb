# %%
from abc import ABC, abstractmethod

class Mobile(ABC):
    @abstractmethod
    def  ram(self):
        pass
    @abstractmethod
    def battery(self):
        pass
    # concrete method
    def about_device(Self):
        return "This is mobile"



class Oppo(Mobile):
    def  __init__(self, model, oppo_ram, oppo_rom, oppo_battery):
        self.model = model
        self.oppo_ram=oppo_ram
        self.oppo_rom=oppo_rom
        self.oppo_battery=oppo_battery

    def ram(self):
        return f"The Oppo {self.model} have {self.oppo_ram}GB RAM"
    def rom(self):
        return f"The Oppo {self.model} have {self.oppo_rom}GB ROM"
    def battery(self):
        return f" The Oppo {self.model} have {self.oppo_battery}GB battery"
        
    def camera(self, front, back):
        return f"The Oppo {self.model} have {front}MP front camera + {back}MP Back camera"

# m = Mobile() # can;t insiate for abstract class
reno16 = Oppo("reno 16", 16, 256, 55000)
reno15 = Oppo("reno 15", 16, 256, 5500)
print(reno16.about_device())
print(reno16.ram())
print(reno16.rom())
# Out:
# This is mobile
# The Oppo reno 16 have 16GB RAM
# The Oppo reno 16 have 256GB ROM

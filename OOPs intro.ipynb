# %%
#create class

class Mobile:
    company = "Iphone"
    def __init__(self,model,ram,rom,price):
        self.model=model
        self.ram = ram
        self.rom= rom
        self.price= price

# object creation

iphone16 = Mobile("iphone 16 " , 16,256,125000)
iphone17 = Mobile("Iphone 17", 8, 256, 120000)
print(iphone16.price)
print(iphone17.price)
print(iphone16.company)
print(iphone17.company)
print(Mobile.company)
# Out:
# 125000
# 120000
# Iphone
# Iphone
# Iphone

# %%
#  Updating Instance attribute data from outside the class

class Mobile:
    company = "Iphone"
    def __init__(self,model,price,ram=8,rom=256):
        self.model=model
        self.ram = ram
        self.rom= rom
        self.price= price

# object creation

iphone16 = Mobile("iphone 16 " , 80000)
iphone17 = Mobile("Iphone 17", 120000,16)
print(iphone16.ram)
iphone16.ram = 16
print(iphone16.ram)
iphone16.company="New Iphone"
print(iphone16.company, iphone17.company)
# Out:
# 8
# 16
# New Iphone Iphone

# %%
class Mobile:
    company = "Apple"

    def __init__(self, model, ram, rom, price):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price

    # Instance Method
    def display(self):
        print("Company :", self.company)
        print("Model   :", self.model)
        print("RAM     :", self.ram, "GB")
        print("ROM     :", self.rom, "GB")
        print("Price   :", self.price)

    # Class Method
    @classmethod
    def change_company(cls, new_company):
        cls.company = new_company

    # Static Method
    @staticmethod
    def discount(price, discount_percent):
        discount_amount = price * discount_percent / 100
        final_price = price - discount_amount
        return final_price


# Object Creation
iphone16 = Mobile("iPhone 16", 16, 256, 125000)
iphone17 = Mobile("iPhone 17", 8, 256, 120000)

# Instance Method
print("----- Mobile 1 Details -----")
iphone16.display()

print("\n----- Mobile 2 Details -----")
iphone17.display()

# Class Method
print("\nChanging Company Name...")
Mobile.change_company("Apple Inc.")

print("\nAfter Changing Company")
print("Mobile 1 Company:", iphone16.company)
print("Mobile 2 Company:", iphone17.company)

# Static Method
print("\nPrice After 10% Discount:")
print("iPhone 16:", Mobile.discount(iphone16.price, 10))
print("iPhone 17:", Mobile.discount(iphone17.price, 10))
# Out:
# ----- Mobile 1 Details -----
# Company : Apple
# Model   : iPhone 16
# RAM     : 16 GB
# ROM     : 256 GB
# Price   : 125000
#
# ----- Mobile 2 Details -----
# Company : Apple
# Model   : iPhone 17
# RAM     : 8 GB
# ROM     : 256 GB
# Price   : 120000
#
# Changing Company Name...
#
# After Changing Company
# Mobile 1 Company: Apple Inc.
# Mobile 2 Company: Apple Inc.
#
# Price After 10% Discount:
# iPhone 16: 112500.0
# iPhone 17: 108000.0

# %%
class Account:
    def __init__(self,name,balance,password):
        self.name = name
        self.balance = balance
        self.password = password
    def withdraw(self,amount):
        if self.balance >= amount:
            self.balance -= amount
            return f"{amount} withdrawal successful"
        return "Insufficient Balance"
    def deposite(self,amount):
        self.balance +=amount
        return f"{amount} Deposite successfully and current Balance is {self.balance}"
user = Account("sakshith",5000,"sakshith@123")
print(user.deposite(1000))
user.balance =10000
print(user.withdraw(50000))
# Out:
# 1000 Deposite successfully and current Balance is 6000
# Insufficient Balance

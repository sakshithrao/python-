# %%
# run time errors 

arr = [10,20,30]

print(arr[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 5
#       1 # run time errors
#       3 arr = [10,20,30]
# ----> 5 print(arr[10])
#
# IndexError: list index out of range

# %%
# Value Error 
arr = [10,20,30]
arr . remove(100)
print(arr[10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 # run time errors
#       2 arr = [10,20,30]
# ----> 3 arr . remove(100)
#       4 print(arr[10])
#
# ValueError: list.remove(x): x not in list

# %%
arr = [10,20,30]
arr,index(100)
print(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 arr = [10,20,30]
# ----> 2 arr,index(100)
#       3 print(arr)
#
# NameError: name 'index' is not defined

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
print(int('abc'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(int('abc'))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
n={'name','sakshith'}
print()
# Out:
#   Cell In[9], line 2
#     print(class)
#           ^
# SyntaxError: invalid syntax

# %%
# Exception handiling
# without exception
try:

    a= int(input())
    b= int(input())
    c = a + b
    print(c)
except:
    print("something wrong in try block")

else:
    print("There is no Exception in try block")
finally:
    print("Program Done")
# Out:
#  2
#  2
# 4
# There is no Exception in try block
# Program Done

# %%
# Exception handiling
# with an  exception
try:

    a= int(input())
    b= int(input())
    c = a + b
    print(c)
except:
    print("something wrong in try block")

else:
    print("There is no Exception in try block")
finally:
    print("Program Done")
# Out:
#  10
#  sakshith
# something wrong in try block
# Program Done

# %%
# Exception handiling
# exception with an exception class
try:

    a = 10
    b = 0
    c = a / b
    print(c)
except  Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
# something wrong in try block:division by zero

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
# Exception handiling
#Define Multiple Exceptions With Difference Except Block
try:

    a = 10
    b = 0
    c = a / b
    print(c)
except ZeroDivisionError as e:
    print(f"Zero division Not Possible: {e}")
except IndexError as e:
    print(f"We can not access element at this position: {e}")
except  Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
# Zero division Not Possible: division by zero

# %%
# Exception handiling
#Define Multiple Exceptions With Difference Except Block
try:
    arr=[1,2,3,4]
    b=arr[10]
    print(b)
except ZeroDivisionError as e:
    print(f"Zero division Not Possible: {e}")
except IndexError as e:
    print(f"We can not access element at this position: {e}")
except Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
# We can not access element at this position: list index out of range

# %%
# Exception handiling
#Define Multiple Exceptions With Difference Except Block
try:

    a = 10
    c= len(a)
    print(c)
except ZeroDivisionError as e:
    print(f"Zero division Not Possible: {e}")
except IndexError as e:
    print(f"We can not access element at this position: {e}")
except  Exception as e:
    print(f"something wrong in try block:{e}")
# Out:
# something wrong in try block:object of type 'int' has no len()
